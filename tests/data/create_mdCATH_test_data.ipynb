# %% [markdown]
# <a href="https://colab.research.google.com/github/icazzaniga/MDIntrinsicDimension/blob/main/tests/data/create_mdCATH_test_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Prepare test trajectory files from mdCATH
#
# Gets `2hbaA00` (NTL9) trajectories from the [mdCATH dataset](https://huggingface.co/datasets/compsciencelab/mdCATH) in HuggingFace and convert them to an XTC+PDB pair.
#
# **Note.** This trajectory is only used for the regression tests. The paper's results are obtained from the extended folding-unfolding trajectories of NTL9 from DESRES (see text and SI).
#
# ## References
#
# > Mirarchi, A., Giorgino, T. & De Fabritiis, G. mdCATH: A Large-Scale MD Dataset for Data-Driven Computational Biophysics. Sci Data 11, 1299 (2024). https://doi.org/10.1038/s41597-024-04140-z. Preprint available at arXiv:2407.14794 (2024).

# %%
# %pip install mdtraj
# Out:
# Collecting mdtraj
#   Downloading mdtraj-1.11.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.6 kB)
# Requirement already satisfied: numpy<3,>=1.25.0 in /usr/local/lib/python3.12/dist-packages (from mdtraj) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mdtraj) (1.16.3)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from mdtraj) (3.2.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from mdtraj) (25.0)
# Downloading mdtraj-1.11.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 30.5 MB/s eta 0:00:00
# Installing collected packages: mdtraj
# Successfully installed mdtraj-1.11.0

# %%
# !uvx hf download --repo-type dataset compsciencelab/mdCATH data/mdcath_dataset_2hbaA00.h5
# Out:
# /root/.cache/huggingface/hub/datasets--compsciencelab--mdCATH/snapshots/5e3ed8aec62b689e01751db16275fdcdbc39e47f/data/mdcath_dataset_2hbaA00.h5

# %%
# !git clone https://github.com/compsciencelab/mdCATH.git
# Out:
# Cloning into 'mdCATH'...
# remote: Enumerating objects: 735, done.
# remote: Counting objects: 100% (735/735), done.
# remote: Compressing objects: 100% (317/317), done.
# remote: Total 735 (delta 419), reused 720 (delta 408), pack-reused 0 (from 0)
# Receiving objects: 100% (735/735), 2.11 MiB | 12.54 MiB/s, done.
# Resolving deltas: 100% (419/419), done.

# %%
# %run mdCATH/user-utils/convert_mdCATH.py   mdcath_dataset_2hbaA00.h5
# Out:
# Wrote 2hbaA00.pdb
# Wrote 2hbaA00_320_0.xtc
# Wrote 2hbaA00_320_1.xtc
# Wrote 2hbaA00_320_2.xtc
# Wrote 2hbaA00_320_3.xtc
# Wrote 2hbaA00_320_4.xtc
# Wrote 2hbaA00_348_0.xtc
# Wrote 2hbaA00_348_1.xtc
# Wrote 2hbaA00_348_2.xtc
# Wrote 2hbaA00_348_3.xtc
# Wrote 2hbaA00_348_4.xtc
# Wrote 2hbaA00_379_0.xtc
# Wrote 2hbaA00_379_1.xtc
# Wrote 2hbaA00_379_2.xtc
# Wrote 2hbaA00_379_3.xtc
# Wrote 2hbaA00_379_4.xtc
# Wrote 2hbaA00_413_0.xtc
# Wrote 2hbaA00_413_1.xtc
# Wrote 2hbaA00_413_2.xtc
# Wrote 2hbaA00_413_3.xtc
# Wrote 2hbaA00_413_4.xtc
# Wrote 2hbaA00_450_0.xtc
# Wrote 2hbaA00_450_1.xtc
# Wrote 2hbaA00_450_2.xtc
# Wrote 2hbaA00_450_3.xtc
# Wrote 2hbaA00_450_4.xtc

# %%
# %ls -l
# Out:
# total 311652
# -rw-r--r-- 1 root root   1613040 Dec  9 14:08 2hbaA00_320_0.xtc
# -rw-r--r-- 1 root root   1612932 Dec  9 14:08 2hbaA00_320_1.xtc
# -rw-r--r-- 1 root root   1613060 Dec  9 14:08 2hbaA00_320_2.xtc
# -rw-r--r-- 1 root root   1613036 Dec  9 14:08 2hbaA00_320_3.xtc
# -rw-r--r-- 1 root root   1613776 Dec  9 14:08 2hbaA00_320_4.xtc
# -rw-r--r-- 1 root root   1612560 Dec  9 14:08 2hbaA00_348_0.xtc
# -rw-r--r-- 1 root root   1612692 Dec  9 14:08 2hbaA00_348_1.xtc
# -rw-r--r-- 1 root root   1612796 Dec  9 14:08 2hbaA00_348_2.xtc
# -rw-r--r-- 1 root root   1614924 Dec  9 14:08 2hbaA00_348_3.xtc
# -rw-r--r-- 1 root root   1614220 Dec  9 14:08 2hbaA00_348_4.xtc
# -rw-r--r-- 1 root root   1613384 Dec  9 14:08 2hbaA00_379_0.xtc
# -rw-r--r-- 1 root root   1613580 Dec  9 14:08 2hbaA00_379_1.xtc
# -rw-r--r-- 1 root root   1614168 Dec  9 14:08 2hbaA00_379_2.xtc
# -rw-r--r-- 1 root root   1613836 Dec  9 14:08 2hbaA00_379_3.xtc
# -rw-r--r-- 1 root root   1613640 Dec  9 14:08 2hbaA00_379_4.xtc
# -rw-r--r-- 1 root root   1617944 Dec  9 14:08 2hbaA00_413_0.xtc
# -rw-r--r-- 1 root root   1612324 Dec  9 14:08 2hbaA00_413_1.xtc
# -rw-r--r-- 1 root root   1614440 Dec  9 14:08 2hbaA00_413_2.xtc
# -rw-r--r-- 1 root root   1614236 Dec  9 14:08 2hbaA00_413_3.xtc
# -rw-r--r-- 1 root root   1613308 Dec  9 14:08 2hbaA00_413_4.xtc
# -rw-r--r-- 1 root root   1619908 Dec  9 14:08 2hbaA00_450_0.xtc
# -rw-r--r-- 1 root root   1619124 Dec  9 14:08 2hbaA00_450_1.xtc
# -rw-r--r-- 1 root root   1616972 Dec  9 14:08 2hbaA00_450_2.xtc
# -rw-r--r-- 1 root root   1615732 Dec  9 14:08 2hbaA00_450_3.xtc
# -rw-r--r-- 1 root root   1618256 Dec  9 14:08 2hbaA00_450_4.xtc
# -rw-r--r-- 1 root root     67580 Dec  9 14:08 2hbaA00.pdb
# drwxr-xr-x 7 root root      4096 Dec  9 13:51 mdCATH/
# -rw-r--r-- 1 root root 278639764 Dec  9 13:46 mdcath_dataset_2hbaA00.h5
# drwxr-xr-x 1 root root      4096 Nov 20 14:30 sample_data/

# %%
# !mdconvert  -t 2hbaA00.pdb -o temp.pdb 2hbaA00_320_0.xtc
# !rm temp.pdb
# Out:
# usage: mdconvert [-h] -o OUTPUT [-c CHUNK] [-f] [-s STRIDE] [-i INDEX]
#                  [-a ATOM_INDICES] [-t TOPOLOGY]
#                  input [input ...]
# mdconvert: error: file exists: temp.pdb
